# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu4064/Thesis_Final/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv')
df.drop('Unnamed: 0', axis = 1)
df.to_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv', index = False)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv')
df2.columns
df2.drop([ 'Unnamed: 0.1', 'Unnamed: 0' ], axis = 1, inplace = True)
df2.to_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv', index = False)

# %%
df3 = pd.read_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv')
df3
# Out:
#                                                   Title  \
# 0                              মুরগির হামলায় শেয়াল নিহত
# 1               বিটিভিতে যেবার আমি ইন্টারভিউ দিতে গেলাম
# 2     বিদেশ থেকে উন্নতমানের বিরোধীদল আমদানি করার পরা...
# 3                         অবসর নেয়ার ঘোষণা দিলেন মেসি !
# 4     মাদারফাকার নহে, ব্রাদারফাকার: সাকা | দৈনিক মতি...
# ...                                                 ...
# 1212                  যে ১০টি কারণে মুখ বন্ধ রাখাই ভালো
# 1213  রাজশাহীতে স্বামীর হাঁচির আওয়াজে ঘুমের মধ্যেই স...
# 1214         শাওমি মোবাইল বিস্ফোরণে কলেজছাত্রের মৃত্যু!
# 1215  ফেসবুকে যেভাবে নতুন মন্ত্রীদের অভিনন্দন বার্তা...
# 1216            মাঝ আকাশে পর্ন দেখার অভিযোগে পাইলট আটক!
#
#                                                 Content  Class
# 0     বাংলায় একটা প্রবাদ আছে, শেয়ালের কাছে মুরগী বর্...      0
# 1     BTV থেকে লোকজন আসছে, ইন্টারভিউ নিবে।চারজনের টি...      0
# 2     অদ্ভুত বিরোধীদলহীনতায় ভুগছে সরকার। এ এক অন্যরক...      0
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/Motikontho.csv')
x = [0]
for i in range(1479):
  x.append(0)
len(x)
df[ 'class' ] = x
df.columns
# Out:
# Index(['headline;body', 'class'], dtype='object')

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Motikontho_Out_csv.csv')
#df.drop('Unnamed: 0', axis = 1, inplace=True)
x = [0]
for i in range(1479):
  x.append(0)
len(x)
df[ 'class' ] = x
df.columns=['Title', 'Content', 'Class']
df.to_csv('/content/drive/MyDrive/dataset/Motikontho_Out_csv.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/Motikontho_Out_csv.csv')
df.to_csv('/content/drive/MyDrive/cur/Motikontho_Out-revised.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/finaldata1_Fake.csv')
df.drop(['Category', 'Source', 'Date' ], axis = 1, inplace=True)
df.replace('\n', '', regex=True, inplace=True)
df.replace('\t', '', regex=True, inplace=True)
df.drop(0, inplace=True)
df.columns = ['Title', 'Content', 'Class']
for i in range(1,len(df)+1):
  df.loc[i, 'Class']=3
df.to_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/label_fake.csv')
df.drop([ 'category', 'label' ], axis=1, inplace=True)
x = []
for i in range(len(df)):
  x.append(3)

df.columns = [ 'Title', 'Content' ]
df['Class'] = x
df.to_csv('/content/drive/MyDrive/cur/label_fake-revised.csv', index=False)

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/cur/BanglaFakeNews500.xlsx')
x = ['Domain']
for i in range(3, 30):
  x.append('Unnamed: ' + str(i))
df.drop(x, axis = 1, inplace = True)
df.columns=[ 'Title', 'Content', 'Class' ]
df.to_csv('/content/drive/MyDrive/cur/BanglaFakeNews500-revised.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv');
for i in range(len(df)):
  x = df.loc[i, 'Content']
  head, sep, tail =  x.partition('Rate')
  while len(head)>0 and head[-1]==' ':
    head = head[:len(head)-1]
  df.loc[i, 'Content'] = head

for i in range(len(df)):
  x = df.loc[i, 'Content']
  if len(x) == 0:
    df.drop(i, inplace=True)

df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df.to_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv');
df
# Out:
#                                                  Title  \
# 0                   আদালতঃ বোলার শাহাদতের কুনো দুষ নাই
# 1                               প্রতিষ্ঠিত হল “এফএফএফ”
# 2                পুটুন এখন ভল্ডামটের নেয় ভয়ংকর: বাফুফে
# 3    ১০ টাকা কেজির চাল সরবরাহে বিলম্বে সুশীল সমাজের...
# 4    কাশিমপুর-২ কারাগারের নাম পরিবর্তন করে “কাশেমঝু...
# ..                                                 ...
# 917  ধারের টাকা না দেয়ায় জোরপূর্বক সোয়েটার পড়িয...
# 918             শেষ বয়সে পক্ষী মারা খেলেন শফিক রেহমান
# 919              রুনা লায়লার হাতে থাবড়া খেলেন ফেরদৌস
# 920  বাটে পেয়ে মুশফিককে সেদিন পিটিয়েছিলেন মুস্তাফ...
# 921  প্রকাশ্যে কলা খাওয়া নিষিদ্ধ হচ্ছে মেয়েদের জন...
#
#                                                Content  Class
# 0    ৫ নম্বর নারী ও শিশু নির্যাতন দমন ট্রাইবুনাল আদ...      3
# 1    নিজস্ব মতিবেদকসমাজ, সংসার ও সরকারের নীপীড়ন নীর...      3
# 2    ক্রীড়া মতিবেদককুরবানীর সিজনে লোকাল নন এসি বাসে...      3
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/BanglaFakeNews500-revised.csv')
df
# Out:
#                                                  Title  \
# 0      টিটুর পাছায় ফোঁড়া হয়েছে ! সবার দোয়াপ্রার্থী
# 1    পাঁচ মাস বগলের লোম না কাটায় বউ চলে গেলো যশোরে...
# 2             সবার আগে চাঁদ দেখতে পেয়েছে যশোরের আরাফাত
# 3               নোয়াখালীতে চ‍াঁদ দেখা গেছে মোট তিনটা !
# 4    বৃষ্টিতে সিগারেট ভিজে যাওয়ায় অঝোরে কাঁদছে পথ...
# ..                                                 ...
# 495        ইসলামী বেংক ছাড়া আমাদের চলেই না: মালাই লামা
# 496  ওপারে তুমি রাধে এপারে আমি, মাঝে মদী বহে রে: মু...
# 497       গৌতম বুদ্ধের বানী, জানি মাগার নাহি মানি: ফখা
# 498                       বংগবন্ধু দুস্টু একটা: খালেদা
# 499                              সময় হইলেই ধরব: কামাল
#
#                                                Content  Class
# 0    ল্টানো তানপুরার মত একটি অঙ্গ। অত্যন্ত তুচ্ছতাচ...      0
# 1    নেক আয়োজন করে বিয়ে করে বাসর ঘরে আনন্দ উল্লাস...      0
# 2    ন্ধ্যার পর চাঁদ দেখা কমিটি থেকে জানানো হয়েছিলো...      2
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv')
df
# Out:
#                                                   Title  \
# 0                              মুরগির হামলায় শেয়াল নিহত
# 1               বিটিভিতে যেবার আমি ইন্টারভিউ দিতে গেলাম
# 2     বিদেশ থেকে উন্নতমানের বিরোধীদল আমদানি করার পরা...
# 3                         অবসর নেয়ার ঘোষণা দিলেন মেসি !
# 4     মাদারফাকার নহে, ব্রাদারফাকার: সাকা | দৈনিক মতি...
# ...                                                 ...
# 1212                  যে ১০টি কারণে মুখ বন্ধ রাখাই ভালো
# 1213  রাজশাহীতে স্বামীর হাঁচির আওয়াজে ঘুমের মধ্যেই স...
# 1214         শাওমি মোবাইল বিস্ফোরণে কলেজছাত্রের মৃত্যু!
# 1215  ফেসবুকে যেভাবে নতুন মন্ত্রীদের অভিনন্দন বার্তা...
# 1216            মাঝ আকাশে পর্ন দেখার অভিযোগে পাইলট আটক!
#
#                                                 Content  Class
# 0     বাংলায় একটা প্রবাদ আছে, শেয়ালের কাছে মুরগী বর্...      0
# 1     BTV থেকে লোকজন আসছে, ইন্টারভিউ নিবে।চারজনের টি...      0
# 2     অদ্ভুত বিরোধীদলহীনতায় ভুগছে সরকার। এ এক অন্যরক...      0
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/Motikontho_Out-revised.csv')
df
# Out:
#                                                  Title  \
# 0                            আদালত বোল শাহাদত কুনো দুষ
# 1     ১০ টাকা কেজির চাল সরবরাহ বিলম্ব সুশীল সমাজ ক্ষোভ
# 2                        পুটুন ভল্ডামট নে ভয়ংকর: বাফুফ
# 3                                  প্রতিষ্ঠিত “এফএফএফ”
# 4                        মাইলস জংগী প্রশিক্ষন দিব: আনু
# ...                                                ...
# 1475                          ইএসপিএন সতর্ক করল আইসিসি
# 1476                     হিলারি ইউনূস ফোন বাংলাদেশ পাশ
# 1477                             শোয়েবরাজ্জাক সুসংবাদ
# 1478  তত্ত্বাবধায়ক সরক ব্যবস্থা বাতিল খেলব না: খালেদা
# 1479         হামাগুড়ি মরুভূমি পাড়ি দেব মুসা ইব্রাহীম
#
#                                                 Content  Class
# 0     ৫ নম্বর নারী শিশু নির্যাতন দমন ট্রাইবুনাল আদাল...      0
# 1     নিজস্ব মতিবেদক ‘খাদ্যবান্ধব’ কর্মসুচীর আওতা ৭ ...      0
# 2     ক্রীড়া মতিবেদক কুরবানীর সিজন লোকাল নন এসি বাস ...      0
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv')
df
# Out:
#                                                  Title  \
# 0                   আদালতঃ বোলার শাহাদতের কুনো দুষ নাই
# 1                               প্রতিষ্ঠিত হল “এফএফএফ”
# 2                পুটুন এখন ভল্ডামটের নেয় ভয়ংকর: বাফুফে
# 3    ১০ টাকা কেজির চাল সরবরাহে বিলম্বে সুশীল সমাজের...
# 4    কাশিমপুর-২ কারাগারের নাম পরিবর্তন করে “কাশেমঝু...
# ..                                                 ...
# 917  ধারের টাকা না দেয়ায় জোরপূর্বক সোয়েটার পড়িয...
# 918             শেষ বয়সে পক্ষী মারা খেলেন শফিক রেহমান
# 919              রুনা লায়লার হাতে থাবড়া খেলেন ফেরদৌস
# 920  বাটে পেয়ে মুশফিককে সেদিন পিটিয়েছিলেন মুস্তাফ...
# 921  প্রকাশ্যে কলা খাওয়া নিষিদ্ধ হচ্ছে মেয়েদের জন...
#
#                                                Content  Class
# 0    ৫ নম্বর নারী ও শিশু নির্যাতন দমন ট্রাইবুনাল আদ...      3
# 1    নিজস্ব মতিবেদকসমাজ, সংসার ও সরকারের নীপীড়ন নীর...      3
# 2    ক্রীড়া মতিবেদককুরবানীর সিজনে লোকাল নন এসি বাসে...      3
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/cur/label_fake-revised.csv');
# Out:
#                                                   Title  \
# 0                                    ৮ দিনে ১৮ বিল পাস!
# 1          আ’লীগের জনসভায় লোকে লোকারণ্য ফেনী ট্রাংক রোড
# 2        মাদ্রাসায় জোড়া খুন: পরিচালক তিন দিনের রিমান্ডে
# 3                এবারেও ঈদে গান শোনাবেন মাহফুজুর রহমান!
# 4             মদ খেলে ভালো ইংরেজি বলা যায় : বলছে গবেষণা
# ...                                                 ...
# 4532         তৃতীয় দিনে মার্শালের ফিফটি, ব্যর্থ আশরাফুল
# 4533                              সরলার সংক্ষিপ্ত জীবনী
# 4534  নাইক্ষ্যংছ‌ড়ি‌তে পু‌লি‌শ-ডাকাত বন্দুকযু‌দ্ধে ন...
# 4535  পরীক্ষা বাতিল হওয়ায় ১ম -৩য় শ্রেণীতে ভর্তি হতে ...
# 4536               এশিয়া কাপে আজ ভারত-পাকিস্তানের মহারণ
#
#                                                 Content  Class
# 0     দশম জাতীয় সংসদের মেয়াদ শেষ হয়ে যাচ্ছে। কার্যত ...      3
# 1     একাদশ জাতীয় সংসদ নির্বাচনকে সামনে রেখে সাংগঠনি...      3
# 2     গাজীপুরে জোড়া খুন মামলার প্রধান আসামি মাদ্রাসা...      3
# ...

# %%
df1 = pd.read_csv('/content/drive/MyDrive/cur/BanglaFakeNews500-revised.csv')
df2 = pd.read_csv('/content/drive/MyDrive/cur/LabeledFake-1K-revised.csv')
df3 = pd.read_csv('/content/drive/MyDrive/cur/Motikontho_Out-revised.csv')
df4 = pd.read_csv('/content/drive/MyDrive/cur/finaldata1_Fake-revised.csv')
df5 = pd.read_csv('/content/drive/MyDrive/cur/label_fake-revised.csv')

df = pd.concat([df1, df2, df3, df4, df5])
df = df.reset_index()
df.columns
df.drop( ['index'], axis=1, inplace=True )
cnt = 0
vis = [0, 0, 0, 0, 0, 0, 0]
for i in range(len(df)):
  c = df.loc[i, 'Class']
  if(vis[c] == 0):
    vis[c] = 1
    cnt = cnt+1

df.drop_duplicates(inplace=True)
df.to_csv('/content/drive/MyDrive/cur/Final_Data.csv', index=False)
print(len(df))
# Out:
# 8561

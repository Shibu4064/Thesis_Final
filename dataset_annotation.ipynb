# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu4064/Thesis_Final/blob/main/dataset_annotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/adil.xlsx")
df2=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/arif.xlsx")
df3=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/ashik (2).xlsx")
df4=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/fardin.xlsx")
df5=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/hashem.xlsx")
df6=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/hridoy (1).xlsx")
df7=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/manik.xlsx")
df8=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/partho.xlsx")
df9=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/rehan..xlsx")
df_ten=pd.read_excel("/content/drive/MyDrive/THESIS/4 2 THESIS/Submission/sakin (2).xlsx")

df_eleven=pd.read_excel("/content/ajoy-final.xlsx")
df_eleven1=df_eleven.filter(regex='^(?!Unnamed)')
df_eleven1.to_excel("/content/ajoy.xlsx",index=False)
df_eleven2=pd.read_excel("/content/ajoy.xlsx")

df_twelve=pd.read_excel("/content/nazrul - nazrul.xlsx")
df_twelve1=df_twelve.filter(regex='^(?!Unnamed)')
df_twelve1.to_excel("/content/nazrul.xlsx",index=False)
df_twelve2=pd.read_excel("/content/nazrul.xlsx")
df_twelve2
# Out:
#                                                Headline  \
# 0                                          অবহেলিত কোকো
# 1                   মনে সাধ, একদিন পেলেনে আগুন দিব: ফখা
# 2     এ বার ধরা যাবে ফেক মেসেজ, নতুন ফিচার আনছে হোয়া...
# 3     অবশেষে পাকিস্তান যুক্তরাস্ট্রের টিসু পেপারের ম...
# 4     লজ্জাজনক: ভিডিও প্রদর্শন করছে কি ভাবে উদার প্র...
# ...                                                 ...
# 1027               আত্ম পরিচ গভীর সংকট কসা কাদের সন্তান
# 1028   লিস্ট ‘এ’ ক্রিকেটের রেকর্ড ভাঙলেন ভারতীয় স্পিনার
# 1029  মিরপুরই হতে যাচ্ছে পৃথিবীর প্রথম আন্ডারওয়াটার ...
# 1030  মৃত চিকিৎসকের রেজিস্ট্রেশন নম্বর ‌ব্যবহার করে ...
# 1031  আজ শেষ হচ্ছে সংস্কৃতি উতসব ‘হে মাকারেনা’ ফেষ্ট...
#
#                                                 Content  Label
# 0     চলমান রাজনীতী নিয়ে গভীর হতাশা বেক্ত করেছেন বৃহ...      0
# 1     বৃহত্তর জামায়াতে ইসলামীর বিএনপি শাখার ভাঁড়প্রা...      0
# 2     ভুয়ো খবর ছড়ানোর অন্যতম হাতিয়ার হয়ে উঠেছে সোশ্...      2
# ...

# %%
df_final_one=pd.concat([df,df2,df3,df4,df5,df6,df7,df8,df9,df_ten])
df_final_1=df_final_one.filter(regex='^(?!Unnamed)')
df_final_1
df_final=pd.concat([df_final_1,df_eleven2,df_twelve2])
df_final.to_excel("/content/annnotated.xlsx",index=False)

# %%
data=pd.read_excel("/content/annnotated.xlsx")
data
# Out:
#                                                 Headline  \
# 0      ছোট্ট বন্ধুর কান ধরে টান দিলেন প্রধানমন্ত্রী ম...
# 1       চার্য নাই যার, সেই আচার্য: ইউনূস | দৈনিক মতিকণ্ঠ
# 2                         নানা ফাঁদে নারী ও তার প্রতিকার
# 3      রাষ্ট্রপতি ট্রুম্প এমন এক নেটওয়ার্ক চায়, যে ...
# 4                        শোচনীয় হারের পর যা বললেন সরফরাজ
# ...                                                  ...
# 12898               আত্ম পরিচ গভীর সংকট কসা কাদের সন্তান
# 12899   লিস্ট ‘এ’ ক্রিকেটের রেকর্ড ভাঙলেন ভারতীয় স্পিনার
# 12900  মিরপুরই হতে যাচ্ছে পৃথিবীর প্রথম আন্ডারওয়াটার ...
# 12901  মৃত চিকিৎসকের রেজিস্ট্রেশন নম্বর ‌ব্যবহার করে ...
# 12902  আজ শেষ হচ্ছে সংস্কৃতি উতসব ‘হে মাকারেনা’ ফেষ্ট...
#
#                                                  Content  Label   .    1
# 0      ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদির ৬৮ বছর পূর...    0.0 NaN  NaN
# 1      স্কটলেন্ড মতিনিধিবাংলাদেশের নোবেল বিজয়ী অর্থন...    0.0 NaN  NaN
# ...

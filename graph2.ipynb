# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu4064/Thesis_Final/blob/main/graph2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data with model names and accuracy values
data = {
    'Model': ['U+SVM', 'B+SVM', 'T+SVM', 'U+B+T', 'C3+SVM', 'C4+SVM', 'C5+SVM', 'C3+C4+C5', 'BanglaBERT','SagorBERT', 'M-BERT-c', 'M-BERT-unc', 'XLM-RoBERTa', 'BLOOM'],
    'F1-Score': [0.74, 0.72, 0.66, 0.75, 0.77, 0.77, 0.77, 0.77, 0.69, 0.79, 0.79,0.81, 0.72, 0.81]
}

# Create a DataFrame
df = pd.DataFrame(data)
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart
df.plot(x='Model', y='F1-Score', kind='bar', legend=False, color='cyan', ax=ax)
plt.title('F1 Scores of Fake Class')
plt.xlabel('Model')
plt.ylabel('F1-Score')
plt.ylim(0, 1)  # Set y-axis limits (0 to 1 for accuracy)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data with model names and accuracy values
data = {
    'Model': ['LR', 'SVM', 'BanglaBERT','SagorBERT', 'M-BERT-c', 'M-BERT-unc', 'XLM-RoBERTa', 'BLOOM'],
    'Accuracy': [0.81, 0.83, 0.85, 0.82, 0.80, 0.83, 0.82, 0.87]
}

# Create a DataFrame
df = pd.DataFrame(data)
fig, ax = plt.subplots(figsize=(10, 6))

# Create a bar chart
df.plot(x='Model', y='Accuracy', kind='bar', legend=False, color='#DFAEB4', ax=ax)
plt.title('Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1)  # Set y-axis limits (0 to 1 for accuracy)
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibu4064/Thesis_Final/blob/main/dataset2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel('/content/drive/MyDrive/dataset/FinalData1.xlsx')
df
# Out:
#                                                   Title  \
# 0        এক দিনে করোনায় মৃত্যু ১৫ জনের, নতুন শনাক্ত ২৬৬
# 1               কোভিড-১৯-এর কাছে মানবজাতি হেরে গেল কেন?
# 2                                   সত্যিকারের ম্যাজিক!
# 3                                      এই সঙ্গনিরোধকালে
# 4                              কী করছেন ঘরবন্দী লেখকেরা
# ...                                                 ...
# 2536  \nপাদ নিয়ে প্রশ্ন করায় সাংবাদিককে ঘাড় দিলেন...
# 2537         \nশেষ বয়সে পক্ষী মারা খেলেন শফিক রেহমান\n
# 2538                \nপ্যান্টের ভেতর সোনা সহ একজন আটক\n
# 2539  \nধারের টাকা না দেয়ায় জোরপূর্বক সোয়েটার পড়...
# 2540  \nপ্রকাশ্যে কলা খাওয়া নিষিদ্ধ হচ্ছে মেয়েদের ...
#
#                                               Statement        Category  \
# 0     \n\nদেশে করোনাভাইরাসে আক্রান্ত হয়ে গত ২৪ ঘণ্টা...  বাংলাদেশ সংবাদ
# 1     \n\nদ্বিতীয় বিশ্বযুদ্ধের পর থেকে বিশ্বের প্রভু...  অন্য আলো সংবাদ
# 2     \n\nবাড়ির পাশেই ভিক্টোরিয়া পার্ক, বিকেল হলেই স...  অন্য আলো সংবাদ
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for (Class), group in df.groupby(['Class']):
     group.to_excel(f'{Class}.xlsx', index=False)

print(pd.read_excel("/content/drive/MyDrive/dataset/finaldata1_Real.xlsx"))
print(pd.read_excel("/content/drive/MyDrive/dataset/finaldata1_Fake.xlsx"))
# Out:
# <ipython-input-6-62d93e175588>:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for (Class), group in df.groupby(['Class']):
#                                                   Title  \
# 0        এক দিনে করোনায় মৃত্যু ১৫ জনের, নতুন শনাক্ত ২৬৬
# 1               কোভিড-১৯-এর কাছে মানবজাতি হেরে গেল কেন?
# 2                                   সত্যিকারের ম্যাজিক!
# 3                                      এই সঙ্গনিরোধকালে
# 4                              কী করছেন ঘরবন্দী লেখকেরা
# ...                                                 ...
# 1543                               করোনার দুটি কুসন্তান
# 1544  সাতকানিয়ায় জ্বর, কাশি ও শ্বাসকষ্ট নিয়ে প্রতিবন...
# 1545  নাটোরে জ্বর, সর্দি ও গলাব্যথা নিয়ে গৃহবধূর মৃত...
# 1546            যেদিন স্বপ্নলোকের চাবি পেয়েছিল বাংলাদেশ
# ...

# %%
df1=pd.read_excel("/content/Fake.xlsx")
df1
# Out:
#                                                  Title  \
# 0    \n\t\t\t\t\t\t\tআদালতঃ বোলার শাহাদতের কুনো দুষ...
# 1    \n\t\t\t\t\t\t\tআদালতঃ বোলার শাহাদতের কুনো দুষ...
# 2    \n\t\t\t\t\t\t\tপ্রতিষ্ঠিত হল “এফএফএফ”\t\t\t\t...
# 3    \n\t\t\t\t\t\t\tপ্রতিষ্ঠিত হল “এফএফএফ”\t\t\t\t...
# 4    \n\t\t\t\t\t\t\tপুটুন এখন ভল্ডামটের নেয় ভয়ংকর:...
# ..                                                 ...
# 988  \nপাদ নিয়ে প্রশ্ন করায় সাংবাদিককে ঘাড় দিলেন...
# 989         \nশেষ বয়সে পক্ষী মারা খেলেন শফিক রেহমান\n
# 990                \nপ্যান্টের ভেতর সোনা সহ একজন আটক\n
# 991  \nধারের টাকা না দেয়ায় জোরপূর্বক সোয়েটার পড়...
# 992  \nপ্রকাশ্যে কলা খাওয়া নিষিদ্ধ হচ্ছে মেয়েদের ...
#
#                                              Statement       Category  \
# 0    \n৫ নম্বর নারী ও শিশু নির্যাতন দমন ট্রাইবুনাল ...     তারার মেলা
# 1    \n৫ নম্বর নারী ও শিশু নির্যাতন দমন ট্রাইবুনাল ...     তারার মেলা
# 2    \nনিজস্ব মতিবেদক\nসমাজ, সংসার ও সরকারের নীপীড়ন...  তথ্যপ্রযুক্তি
# ...

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/gulzar09/Bangla_Fake-Real_News_Small_Dataset.git
# Out:
# fatal: destination path 'Bangla_Fake-Real_News_Small_Dataset' already exists and is not an empty directory.

# %%
df2=pd.read_excel('/content/All data.xlsx')
df2
# Out:
#                                            Page Name    User Name  \
# 0                                            Ekattor   ekattor.tv
# 1      Corona facebook awareness group in Bangladesh          NaN
# 2                                            বিশ্বাস  ARBIswas851
# 3                                     প্রিয় বাংলাদেশ          NaN
# 4                                           FoodRank          NaN
# ..                                               ...          ...
# 852                                         তাজা খবর          NaN
# 853  Narendra Modi- The Best Prime Minister Of India          NaN
# 854              BJP West Bengal (বিজেপি পশ্চিমবঙ্গ)          NaN
# 855                                              NaN          NaN
# 856                                              NaN          NaN
#
#       Facebook Id  Likes at Posting  Followers at Posting  \
# 0    3.326563e+14         5179335.0             5711215.0
# ...

# %%
df3=pd.read_csv('/content/drive/MyDrive/dataset/final_bn_data.csv')
df3
# Out:
#         category                                           headline  \
# 0       National                                 ৮ দিনে ১৮ বিল পাস!
# 1         Sports       আ’লীগের জনসভায় লোকে লোকারণ্য ফেনী ট্রাংক রোড
# 2       National     মাদ্রাসায় জোড়া খুন: পরিচালক তিন দিনের রিমান্ডে
# 3         Sports           নেপালকে হারিয়ে গ্রুপ চ্যাম্পিয়ন বাংলাদেশ
# 4       National                কুড়িগ্রামে ২ শিক্ষার্থীর লাশ উদ্ধার
# ...          ...                                                ...
# 14532   National  নাইক্ষ্যংছ‌ড়ি‌তে পু‌লি‌শ-ডাকাত বন্দুকযু‌দ্ধে ন...
# 14533      Crime  এবি ব্যাংকের প্রাক্তন চেয়ারম্যানসহ ৪ জনকে জিজ্...
# 14534  Education  পরীক্ষা বাতিল হওয়ায় ১ম -৩য় শ্রেণীতে ভর্তি হতে ...
# 14535     Sports               এশিয়া কাপে আজ ভারত-পাকিস্তানের মহারণ
# 14536  Lifestyle                           অনলাইনে পোশাক কিনলেই ছাড়
#
#                                                  content  label
# 0      দশম জাতীয় সংসদের মেয়াদ শেষ হয়ে যাচ্ছে। কার্যত ...    0.0
# ...

# %%
real = df3[df3['label'] == 1.0]
fake = df3[df3['label'] == 0.0]

real.to_csv('label_real.csv', index=False)
fake.to_csv('label_fake.csv', index=False)

print(pd.read_csv("label_real.csv"))
print(pd.read_csv("label_fake.csv"))
# Out:
#            category                                           headline  \
# 0            Sports           নেপালকে হারিয়ে গ্রুপ চ্যাম্পিয়ন বাংলাদেশ
# 1          National                কুড়িগ্রামে ২ শিক্ষার্থীর লাশ উদ্ধার
# 2          National  মেহেরপুরে দ্বিতীয় শ্রেণির দুই ছাত্রীকে ধর্ষনের...
# 3           Finance   সিলভা ফার্মায় ২৮ টাকা মুনাফা পেলেন বিনিয়োগকারীরা
# 4         Editorial  প্রথম কার্যদিবসেই ৭৫২ কোটি টাকার প্রকল্পে স্বা...
# ...             ...                                                ...
# 9995  International                          পদত্যাগ করলেন নিকি হ্যালি
# 9996       National                    নারায়ণগঞ্জে ২ তরুণের লাশ, আটক ৩
# 9997       National    শিশু অধিকার সুরক্ষায় দেশ এগিয়ে: কাজী রিয়াজুল হক
# 9998          Crime  এবি ব্যাংকের প্রাক্তন চেয়ারম্যানসহ ৪ জনকে জিজ্...
# 9999      Lifestyle                           অনলাইনে পোশাক কিনলেই ছাড়
#
#                                                 content  label
# ...

# %%
data=pd.read_csv("/content/label_fake.csv")
data
# Out:
#            category                                           headline  \
# 0          National                                 ৮ দিনে ১৮ বিল পাস!
# 1            Sports       আ’লীগের জনসভায় লোকে লোকারণ্য ফেনী ট্রাংক রোড
# 2          National     মাদ্রাসায় জোড়া খুন: পরিচালক তিন দিনের রিমান্ডে
# 3     Entertainment             এবারেও ঈদে গান শোনাবেন মাহফুজুর রহমান!
# 4         Lifestyle          মদ খেলে ভালো ইংরেজি বলা যায় : বলছে গবেষণা
# ...             ...                                                ...
# 4532         Sports         তৃতীয় দিনে মার্শালের ফিফটি, ব্যর্থ আশরাফুল
# 4533  Miscellaneous                              সরলার সংক্ষিপ্ত জীবনী
# 4534       National  নাইক্ষ্যংছ‌ড়ি‌তে পু‌লি‌শ-ডাকাত বন্দুকযু‌দ্ধে ন...
# 4535      Education  পরীক্ষা বাতিল হওয়ায় ১ম -৩য় শ্রেণীতে ভর্তি হতে ...
# 4536         Sports               এশিয়া কাপে আজ ভারত-পাকিস্তানের মহারণ
#
#                                                 content  label
# ...

# %%
df4=pd.read_csv('/content/LabeledFake-1K.csv')

df4
# Out:
#       articleID                    domain                        date  \
# 0             1         channeldhaka.news   2019-03-14T13:34:14+00:00
# 1             2                 earki.com            সেম্বর ১৭, ২০১৮
# 2             3                 earki.com  ২০:৩৯, জানুয়ারি ১৪, ২০১৯
# 3             4         channeldhaka.news   2018-06-30T15:56:47+00:00
# 4             5  motikontho.wordpress.com   2013-03-05T21:55:45+00:00
# ...         ...                       ...                         ...
# 1294       1303           bengalbeats.com   2019-03-31T21:34:42+00:00
# 1295       1304      bengaliviralnews.com   2018-01-16T15:36:12+00:00
# 1296       1305         channeldhaka.news   2018-12-03T18:09:08+00:00
# 1297       1306                 earki.com  ১৭:৩৬, জানুয়ারি ০৭, ২০১৯
# 1298       1307         channeldhaka.news   2019-03-09T23:00:05+00:00
#
#            category                         source   relation  \
# 0     International                       Reporter  Unrelated
# ...

# %%
df_ajaira= pd.read_excel("/content/drive/MyDrive/Bangla_Fake-Real_News_Small_Dataset/FinalData1.xlsx")
len(df_ajaira)
# Out:
# 2541

# %%
import os
os.environ["KAGGLE_USERNAME"]="hrithikmajumdar"
os.environ["KAGGLE_KEY"]="900893b210bb5b73684e096e83fe75ec"

# %%
#https://ieeexplore.ieee.org/document/9579777

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/mridul133/Satire-Detection.git
# Out:
# Cloning into 'Satire-Detection'...
# remote: Enumerating objects: 255, done.
# remote: Total 255 (delta 0), reused 0 (delta 0), pack-reused 255
# Receiving objects: 100% (255/255), 124.33 MiB | 10.83 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Updating files: 100% (239/239), done.

# %%
import pandas as pd

df = pd.read_json("/content/drive/MyDrive/Satire-Detection/Implementation/tfidf_model/Motikontho_Out.json")
df
# Out:
#                                               headline  \
# 0                            আদালত বোল শাহাদত কুনো দুষ
# 1     ১০ টাকা কেজির চাল সরবরাহ বিলম্ব সুশীল সমাজ ক্ষোভ
# 2                        পুটুন ভল্ডামট নে ভয়ংকর: বাফুফ
# 3                                  প্রতিষ্ঠিত “এফএফএফ”
# 4                        মাইলস জংগী প্রশিক্ষন দিব: আনু
# ...                                                ...
# 1475                          ইএসপিএন সতর্ক করল আইসিসি
# 1476                     হিলারি ইউনূস ফোন বাংলাদেশ পাশ
# 1477                             শোয়েবরাজ্জাক সুসংবাদ
# 1478  তত্ত্বাবধায়ক সরক ব্যবস্থা বাতিল খেলব না: খালেদা
# 1479         হামাগুড়ি মরুভূমি পাড়ি দেব মুসা ইব্রাহীম
#
#                                                    body
# 0     ৫ নম্বর নারী শিশু নির্যাতন দমন ট্রাইবুনাল আদাল...
# 1     নিজস্ব মতিবেদক ‘খাদ্যবান্ধব’ কর্মসুচীর আওতা ৭ ...
# 2     ক্রীড়া মতিবেদক কুরবানীর সিজন লোকাল নন এসি বাস ...
# 3     নিজস্ব মতিবেদক সমাজ সংস সরকার নীপীড়ন নীর্যাতন ...
# ...

# %%
df7=pd.read_excel('/content/BanglaFakeNews500.xlsx')
df7
# Out:
#                                                 Domain  \
# 0    https://web.archive.org/web/20190704042344/htt...
# 1    https://web.archive.org/web/20190706174747/htt...
# 2    https://web.archive.org/web/20190709155348/htt...
# 3    https://web.archive.org/web/20190708084046/htt...
# 4    https://web.archive.org/web/20190621125742/htt...
# ..                                                 ...
# 495  https://web.archive.org/web/20140511122046/htt...
# 496  https://web.archive.org/web/20140518105607/htt...
# 497  https://web.archive.org/web/20140518084651/htt...
# 498  https://web.archive.org/web/20140518084646/htt...
# 499  https://web.archive.org/web/20140515212427/htt...
#
#                                               headline  \
# 0      টিটুর পাছায় ফোঁড়া হয়েছে ! সবার দোয়াপ্রার্থী
# 1    পাঁচ মাস বগলের লোম না কাটায় বউ চলে গেলো যশোরে...
# 2             সবার আগে চাঁদ দেখতে পেয়েছে যশোরের আরাফাত
# 3               নোয়াখালীতে চ‍াঁদ দেখা গেছে মোট তিনটা !
# ...

# %%
import pandas as pd
df9=pd.read_csv("/content/train(4).csv")
df9
# Out:
#        label                                               text
# 0          1  হট্টগোল করায় বাকৃবিতে দুইজন বরখাস্ত, ৬ জনকে শো...
# 1          1  মালয়েশিয়ায় কর্মী পাঠানোর ব্যবস্থা নেয়ার সুপারি...
# 2          1  প্রেমের প্রস্তাবে রাজি না হওয়ায় স্কুলছাত্রীকে ...
# 3          1  মেডিয়েশনই মামলাজট নিরসনের পথ : বিচারপতি আহমেদ ...
# 4          1  টকশোতে বক্তব্য দিতে গিয়ে জাপা নেতার মৃত্যুমাদা...
# ...      ...                                                ...
# 10011      0  নৈতিকতা লঙ্ঘনের জন্য নিষিদ্ধ করা হয়েছে: “...স...
# 10012      0  ম্যাকডোনাল্ডসে সহিংস গ্যাং বিটিংয়ের জন্য ১৬ ব...
# 10013      0  “অসহিংসতা ’ কাজ করেনি...রেভারেন্ড স্যাম মোস্তে...
# 10014      0  ডার্টি হ্যারি রমনি’স ট্যাক্সের ব্যাপারে তার মি...
# 10015      0  হিলারি রডহাম নিক্সন: স্যামসোনাইট ফ্যাক্টরির চে...
#
# [10016 rows x 2 columns]

# %%
import pandas as pd
data=pd.read_excel("/content/BanglaFakeNews500.xlsx")
data.shape
data.head()
# Out:
#                                               Domain  \
# 0  https://web.archive.org/web/20190704042344/htt...
# 1  https://web.archive.org/web/20190706174747/htt...
# 2  https://web.archive.org/web/20190709155348/htt...
# 3  https://web.archive.org/web/20190708084046/htt...
# 4  https://web.archive.org/web/20190621125742/htt...
#
#                                             headline  \
# 0    টিটুর পাছায় ফোঁড়া হয়েছে ! সবার দোয়াপ্রার্থী
# 1  পাঁচ মাস বগলের লোম না কাটায় বউ চলে গেলো যশোরে...
# 2           সবার আগে চাঁদ দেখতে পেয়েছে যশোরের আরাফাত
# 3             নোয়াখালীতে চ‍াঁদ দেখা গেছে মোট তিনটা !
# 4  বৃষ্টিতে সিগারেট ভিজে যাওয়ায় অঝোরে কাঁদছে পথ...
#
#                                              Content Unnamed: 3  Unnamed: 4  \
# 0  ল্টানো তানপুরার মত একটি অঙ্গ। অত্যন্ত তুচ্ছতাচ...        NaN         NaN
# 1  নেক আয়োজন করে বিয়ে করে বাসর ঘরে আনন্দ উল্লাস...        NaN         NaN
# 2  ন্ধ্যার পর চাঁদ দেখা কমিটি থেকে জানানো হয়েছিলো...        NaN         NaN
# ...
